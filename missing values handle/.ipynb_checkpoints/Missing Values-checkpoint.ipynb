# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
np.random.seed(42)

data = pd.DataFrame({
    "Experience": np.random.randint(0, 15, 500),
    "Salary": np.random.randint(20000, 150000, 500),
    "Education": np.random.choice(["Graduate", "PostGraduate", "PhD"], 500),
    "Department": np.random.choice(["IT", "HR", "Finance", "Sales"], 500),
    "Performance_Score": np.random.randint(40, 100, 500)
})

# %%
for col in data.columns:
    data.loc[data.sample(frac=0.1).index, col] = np.nan

# %%
data
# Out:
#      Experience    Salary     Education Department  Performance_Score
# 0           6.0   70993.0           PhD         HR               47.0
# 1           3.0       NaN           PhD      Sales               59.0
# 2          12.0   30647.0      Graduate         HR               68.0
# 3           NaN   28716.0      Graduate         IT               93.0
# 4          10.0  108891.0           NaN         IT               92.0
# ..          ...       ...           ...        ...                ...
# 495        12.0   82292.0      Graduate         IT               80.0
# 496         9.0       NaN      Graduate    Finance               75.0
# 497         6.0   24158.0           PhD      Sales               97.0
# 498         9.0   82680.0           PhD      Sales               92.0
# 499         2.0   40309.0  PostGraduate    Finance               73.0
#
# [500 rows x 5 columns]

# %%
data.isnull()
# Out:
#      Experience  Salary  Education  Department  Performance_Score
# 0         False   False      False       False              False
# 1         False    True      False       False              False
# 2         False   False      False       False              False
# 3          True   False      False       False              False
# 4         False   False       True       False              False
# ..          ...     ...        ...         ...                ...
# 495       False   False      False       False              False
# 496       False    True      False       False              False
# 497       False   False      False       False              False
# 498       False   False      False       False              False
# 499       False   False      False       False              False
#
# [500 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# Experience           50
# Salary               50
# Education            50
# Department           50
# Performance_Score    50
# dtype: int64

# %%
data["Salary"].median()
# Out:
# 85996.5

# %%
data["Experience"].fillna(data["Experience"].median(), inplace=True)
# Out:
# C:\Users\Imnag\AppData\Local\Temp\ipykernel_2220\3060047872.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Experience"].fillna(data["Experience"].median(), inplace=True)

# %%
data.isnull().sum()
# Out:
# Experience            0
# Salary               50
# Education            50
# Department           50
# Performance_Score    50
# dtype: int64

# %%
data["Salary"].median()
# Out:
# 85996.5

# %%
data["Salary"].fillna(data["Salary"].median(),inplace=True)
# Out:
# C:\Users\Imnag\AppData\Local\Temp\ipykernel_2220\1069493069.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Salary"].fillna(data["Salary"].median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Experience            0
# Salary                0
# Education            50
# Department           50
# Performance_Score    50
# dtype: int64

# %%
data["Performance_Score"].fillna(data["Performance_Score"].median(), inplace=True)
# Out:
# C:\Users\Imnag\AppData\Local\Temp\ipykernel_2220\1754094650.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Performance_Score"].fillna(data["Performance_Score"].median(), inplace=True)

# %%
data["Education"].fillna(data["Education"].mode()[0],inplace=True)
# Out:
# C:\Users\Imnag\AppData\Local\Temp\ipykernel_2220\1320301307.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Education"].fillna(data["Education"].mode()[0],inplace=True)

# %%
data["Department"].fillna(data["Department"].mode()[0],inplace=True)
# Out:
# C:\Users\Imnag\AppData\Local\Temp\ipykernel_2220\2560428250.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Department"].fillna(data["Department"].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# Experience           0
# Salary               0
# Education            0
# Department           0
# Performance_Score    0
# dtype: int64

# %%
data.head(10)
# Out:
#    Experience    Salary     Education Department  Performance_Score
# 0         6.0   70993.0           PhD         HR               47.0
# 1         3.0   85996.5           PhD      Sales               59.0
# 2        12.0   30647.0      Graduate         HR               68.0
# 3         7.0   28716.0      Graduate         IT               93.0
# 4        10.0  108891.0           PhD         IT               92.0
# 5         7.0  107545.0  PostGraduate         IT               90.0
# 6        12.0  137638.0           PhD         IT               84.0
# 7         4.0  109912.0           PhD      Sales               85.0
# 8         6.0   85996.5           PhD         IT               49.0
# 9         9.0   90316.0      Graduate         IT               82.0

# %%
data
# Out:
#      Experience    Salary     Education Department  Performance_Score
# 0           6.0   70993.0           PhD         HR               47.0
# 1           3.0   85996.5           PhD      Sales               59.0
# 2          12.0   30647.0      Graduate         HR               68.0
# 3           7.0   28716.0      Graduate         IT               93.0
# 4          10.0  108891.0           PhD         IT               92.0
# ..          ...       ...           ...        ...                ...
# 495        12.0   82292.0      Graduate         IT               80.0
# 496         9.0   85996.5      Graduate    Finance               75.0
# 497         6.0   24158.0           PhD      Sales               97.0
# 498         9.0   82680.0           PhD      Sales               92.0
# 499         2.0   40309.0  PostGraduate    Finance               73.0
#
# [500 rows x 5 columns]

# %%
data.head()
# Out:
#    Experience    Salary Education Department  Performance_Score
# 0         6.0   70993.0       PhD         HR               47.0
# 1         3.0   85996.5       PhD      Sales               59.0
# 2        12.0   30647.0  Graduate         HR               68.0
# 3         7.0   28716.0  Graduate         IT               93.0
# 4        10.0  108891.0       PhD         IT               92.0

# %%
pd.get_dummies(data)
# Out:
#      Experience    Salary  Performance_Score  Education_Graduate  \
# 0           6.0   70993.0               47.0               False
# 1           3.0   85996.5               59.0               False
# 2          12.0   30647.0               68.0                True
# 3           7.0   28716.0               93.0                True
# 4          10.0  108891.0               92.0               False
# ..          ...       ...                ...                 ...
# 495        12.0   82292.0               80.0                True
# 496         9.0   85996.5               75.0                True
# 497         6.0   24158.0               97.0               False
# 498         9.0   82680.0               92.0               False
# 499         2.0   40309.0               73.0               False
#
#      Education_PhD  Education_PostGraduate  Department_Finance  Department_HR  \
# 0             True                   False               False           True
# 1             True                   False               False          False
# 2            False                   False               False           True
# 3            False                   False               False          False
# 4             True                   False               False          False
# ..             ...                     ...                 ...            ...
# 495          False                   False               False          False
# 496          False                   False                True          False
# 497           True                   False               False          False
# 498           True                   False               False          False
# 499          False                    True                True          False
#
#      Department_IT  Department_Sales
# 0            False             False
# 1            False              True
# 2            False             False
# 3             True             False
# 4             True             False
# ..             ...               ...
# 495           True             False
# 496          False             False
# 497          False              True
# 498          False              True
# 499          False             False
#
# [500 rows x 10 columns]

# %%
pd.get_dummies(data)
# Out:
#      Experience    Salary  Performance_Score  Education_Graduate  \
# 0           6.0   70993.0               47.0               False
# 1           3.0   85996.5               59.0               False
# 2          12.0   30647.0               68.0                True
# 3           7.0   28716.0               93.0                True
# 4          10.0  108891.0               92.0               False
# ..          ...       ...                ...                 ...
# 495        12.0   82292.0               80.0                True
# 496         9.0   85996.5               75.0                True
# 497         6.0   24158.0               97.0               False
# 498         9.0   82680.0               92.0               False
# 499         2.0   40309.0               73.0               False
#
#      Education_PhD  Education_PostGraduate  Department_Finance  Department_HR  \
# 0             True                   False               False           True
# 1             True                   False               False          False
# 2            False                   False               False           True
# 3            False                   False               False          False
# 4             True                   False               False          False
# ..             ...                     ...                 ...            ...
# 495          False                   False               False          False
# 496          False                   False                True          False
# 497           True                   False               False          False
# 498           True                   False               False          False
# 499          False                    True                True          False
#
#      Department_IT  Department_Sales
# 0            False             False
# 1            False              True
# 2            False             False
# 3             True             False
# 4             True             False
# ..             ...               ...
# 495           True             False
# 496          False             False
# 497          False              True
# 498          False              True
# 499          False             False
#
# [500 rows x 10 columns]

# %%
data
# Out:
#      Experience    Salary     Education Department  Performance_Score
# 0           6.0   70993.0           PhD         HR               47.0
# 1           3.0   85996.5           PhD      Sales               59.0
# 2          12.0   30647.0      Graduate         HR               68.0
# 3           7.0   28716.0      Graduate         IT               93.0
# 4          10.0  108891.0           PhD         IT               92.0
# ..          ...       ...           ...        ...                ...
# 495        12.0   82292.0      Graduate         IT               80.0
# 496         9.0   85996.5      Graduate    Finance               75.0
# 497         6.0   24158.0           PhD      Sales               97.0
# 498         9.0   82680.0           PhD      Sales               92.0
# 499         2.0   40309.0  PostGraduate    Finance               73.0
#
# [500 rows x 5 columns]

# %%
pd.get_dummies(data)
# Out:
#      Experience    Salary  Performance_Score  Education_Graduate  \
# 0           6.0   70993.0               47.0               False
# 1           3.0   85996.5               59.0               False
# 2          12.0   30647.0               68.0                True
# 3           7.0   28716.0               93.0                True
# 4          10.0  108891.0               92.0               False
# ..          ...       ...                ...                 ...
# 495        12.0   82292.0               80.0                True
# 496         9.0   85996.5               75.0                True
# 497         6.0   24158.0               97.0               False
# 498         9.0   82680.0               92.0               False
# 499         2.0   40309.0               73.0               False
#
#      Education_PhD  Education_PostGraduate  Department_Finance  Department_HR  \
# 0             True                   False               False           True
# 1             True                   False               False          False
# 2            False                   False               False           True
# 3            False                   False               False          False
# 4             True                   False               False          False
# ..             ...                     ...                 ...            ...
# 495          False                   False               False          False
# 496          False                   False                True          False
# 497           True                   False               False          False
# 498           True                   False               False          False
# 499          False                    True                True          False
#
#      Department_IT  Department_Sales
# 0            False             False
# 1            False              True
# 2            False             False
# 3             True             False
# 4             True             False
# ..             ...               ...
# 495           True             False
# 496          False             False
# 497          False              True
# 498          False              True
# 499          False             False
#
# [500 rows x 10 columns]

# %%
pd.get_dummies(data, drop_first=True)
# Out:
#      Experience    Salary  Performance_Score  Education_PhD  \
# 0           6.0   70993.0               47.0           True
# 1           3.0   85996.5               59.0           True
# 2          12.0   30647.0               68.0          False
# 3           7.0   28716.0               93.0          False
# 4          10.0  108891.0               92.0           True
# ..          ...       ...                ...            ...
# 495        12.0   82292.0               80.0          False
# 496         9.0   85996.5               75.0          False
# 497         6.0   24158.0               97.0           True
# 498         9.0   82680.0               92.0           True
# 499         2.0   40309.0               73.0          False
#
#      Education_PostGraduate  Department_HR  Department_IT  Department_Sales
# 0                     False           True          False             False
# 1                     False          False          False              True
# 2                     False           True          False             False
# 3                     False          False           True             False
# 4                     False          False           True             False
# ..                      ...            ...            ...               ...
# 495                   False          False           True             False
# 496                   False          False          False             False
# 497                   False          False          False              True
# 498                   False          False          False              True
# 499                    True          False          False             False
#
# [500 rows x 8 columns]

# %%
data_encoded.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 data_encoded.head()
#
# NameError: name 'data_encoded' is not defined

# %%
data.head()
# Out:
#    Experience    Salary Education Department  Performance_Score
# 0         6.0   70993.0       PhD         HR               47.0
# 1         3.0   85996.5       PhD      Sales               59.0
# 2        12.0   30647.0  Graduate         HR               68.0
# 3         7.0   28716.0  Graduate         IT               93.0
# 4        10.0  108891.0       PhD         IT               92.0
